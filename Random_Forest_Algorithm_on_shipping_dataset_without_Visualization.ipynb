# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('/content/shipping.csv')
df
# Out:
#           ID Warehouse_block Mode_of_Shipment  Customer_care_calls  \
# 0          1               D           Flight                    4
# 1          2               F           Flight                    4
# 2          3               A           Flight                    2
# 3          4               B           Flight                    3
# 4          5               C           Flight                    2
# ...      ...             ...              ...                  ...
# 10994  10995               A             Ship                    4
# 10995  10996               B             Ship                    4
# 10996  10997               C             Ship                    5
# 10997  10998               F             Ship                    5
# 10998  10999               D             Ship                    2
#
#        Customer_rating  Cost_of_the_Product  Prior_purchases  \
# 0                    2                  177                3
# ...

# %%
df.describe()
# Out:
#                 ID  Customer_care_calls  Customer_rating  Cost_of_the_Product  \
# count  10999.00000         10999.000000     10999.000000         10999.000000
# mean    5500.00000             4.054459         2.990545           210.196836
# std     3175.28214             1.141490         1.413603            48.063272
# min        1.00000             2.000000         1.000000            96.000000
# 25%     2750.50000             3.000000         2.000000           169.000000
# 50%     5500.00000             4.000000         3.000000           214.000000
# 75%     8249.50000             5.000000         4.000000           251.000000
# max    10999.00000             7.000000         5.000000           310.000000
#
#        Prior_purchases  Discount_offered  Weight_in_gms  Reached.on.Time_Y.N
# count     10999.000000      10999.000000   10999.000000         10999.000000
# mean          3.567597         13.373216    3634.016729             0.596691
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10999 entries, 0 to 10998
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ID                   10999 non-null  int64
#  1   Warehouse_block      10999 non-null  object
#  2   Mode_of_Shipment     10999 non-null  object
#  3   Customer_care_calls  10999 non-null  int64
#  4   Customer_rating      10999 non-null  int64
#  5   Cost_of_the_Product  10999 non-null  int64
#  6   Prior_purchases      10999 non-null  int64
#  7   Product_importance   10999 non-null  object
#  8   Gender               10999 non-null  object
#  9   Discount_offered     10999 non-null  int64
#  10  Weight_in_gms        10999 non-null  int64
#  11  Reached.on.Time_Y.N  10999 non-null  int64
# dtypes: int64(8), object(4)
# memory usage: 1.0+ MB

# %%
df.isnull().sum()
# Out:
# ID                     0
# Warehouse_block        0
# Mode_of_Shipment       0
# Customer_care_calls    0
# Customer_rating        0
# Cost_of_the_Product    0
# Prior_purchases        0
# Product_importance     0
# Gender                 0
# Discount_offered       0
# Weight_in_gms          0
# Reached.on.Time_Y.N    0
# dtype: int64

# %%
df['Reached.on.Time_Y.N']
# Out:
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1
#         ..
# 10994    1
# 10995    0
# 10996    0
# 10997    0
# 10998    0
# Name: Reached.on.Time_Y.N, Length: 10999, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
a=LabelEncoder()
for col in df.columns:
  df[col]=a.fit_transform(df[col])

# %%
df['Reached.on.Time_Y.N']
# Out:
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1
#         ..
# 10994    1
# 10995    0
# 10996    0
# 10997    0
# 10998    0
# Name: Reached.on.Time_Y.N, Length: 10999, dtype: int64

# %%
dfc=df.corr()
sns.heatmap(dfc,annot=True,linewidths=1)
# Out:
# <Axes: >

# %%
x=df.drop('Reached.on.Time_Y.N',axis=1)
y=df['Reached.on.Time_Y.N']

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=1)

# %%
x_train
# Out:
#           ID  Warehouse_block  Mode_of_Shipment  Customer_care_calls  \
# 1169    1169                4                 2                    4
# 3027    3027                1                 0                    1
# 7635    7635                1                 2                    0
# 7267    7267                4                 0                    3
# 10193  10193                4                 2                    4
# ...      ...              ...               ...                  ...
# 7813    7813                4                 0                    2
# 10955  10955                4                 0                    0
# 905      905                4                 2                    2
# 5192    5192                0                 1                    3
# 235      235                4                 2                    0
#
#        Customer_rating  Cost_of_the_Product  Prior_purchases  \
# 1169                 0                  161                1
# ...

# %%
y_train
# Out:
# 1169     1
# 3027     1
# 7635     0
# 7267     1
# 10193    1
#         ..
# 7813     0
# 10955    0
# 905      1
# 5192     1
# 235      1
# Name: Reached.on.Time_Y.N, Length: 8249, dtype: int64

# %%
from sklearn.preprocessing import StandardScaler

# %%
a=StandardScaler()
a.fit_transform(x_train)
# Out:
# array([[-1.36746778,  1.11560102,  0.63666798, ...,  1.00595786,
#          1.47601128, -0.77031288],
#        [-0.78232026, -0.89971239, -2.02183577, ..., -0.99407742,
#         -0.01751714, -0.99733115],
#        [ 0.66889597, -0.89971239,  0.63666798, ..., -0.99407742,
#         -0.51535994,  1.36091205],
#        ...,
#        [-1.45061038,  1.11560102,  0.63666798, ...,  1.00595786,
#         -0.01751714, -1.55477816],
#        [-0.10048799, -1.57148353, -0.6925839 , ...,  1.00595786,
#         -0.32866889,  0.8794071 ],
#        [-1.66161621,  1.11560102,  0.63666798, ...,  1.00595786,
#          1.53824163, -1.39319931]])

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
clf=RandomForestClassifier(random_state=70,n_jobs=-1,max_depth=10,n_estimators=100,max_features=20,oob_score=True,criterion='entropy',max_leaf_nodes=20)

# %%
clf.fit(x_train,y_train)
# Out:
# RandomForestClassifier(criterion='entropy', max_depth=10, max_features=20,
#                        max_leaf_nodes=20, n_jobs=-1, oob_score=True,
#                        random_state=70)

# %%
y_pred=clf.predict(x_test)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test,y_pred)
# Out:
# 0.6901818181818182
